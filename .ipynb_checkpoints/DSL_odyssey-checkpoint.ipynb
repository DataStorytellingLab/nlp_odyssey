# %% [markdown]
# # Text Processing with Python
# The goal of this workshop is to process, annotate, and analyze text in order to enable
# analysis and insights.
#
# To do so, we will be working with the Python programming langauge, and in particular, a package called [spaCy](https://spacy.io/), which was designed to work with text-based data. With spaCy, which is the industry standard for text-based analysis, we will extract patterns based on linguistic elements.
#
# The dataset we will use comes from three translations of *The Odyssey*:
# - Emily Wilson (2017)
# - Robert Fagles (1996)
# - Alexander Pope (1725)
#
# The datasets are in plain .txt format, which we will download either through the repository link.
#
# From this dataset, we will ask questions about the basic plot of the story and explore characterization.
#
# Let's jump in!

# %% [markdown]
# ## loading our libraries and dataset

# %%
# importing our spacy and pandas libraries
import spacy
import pandas as pd

# loading up the model in english
nlp = spacy.load("en_core_web_sm")

# %%
with open("wilson.txt", "r") as f:
    wilson_text = f.read()
    f.close()

# %% [markdown]
# Using a "slice" to see the first 100 characters

# %%
wilson_text[:100]
# Out:
# The Boy and the Goddess
# Tell me about a complicated man.
# Muse, tell me how he wandered and was lost

# %% [markdown]
# Some light cleaning
# - removing the "/n" character
# - using python function `replace()`

# %%
# replace '/n' with a space
wilson_text = wilson_text.replace('\n', ' ')

# %%
wilson_text[:100]
# Out:
# 'The Boy and the Goddess Tell me about a complicated man. Muse, tell me how he wandered and was lost '

# %% [markdown]
# ## the `Doc` object
# When we pass the texts into the `nlp()` function, we transforming it into a `Doc` type of object in spaCy. Read more about the spaCy pipeline here: https://spacy.io/usage/spacy-101#pipelines

# %%
wilson = nlp(wilson_text)

# %%
# see more about Doc objects in spaCy documentation
# https://spacy.io/api/doc

type(wilson)
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# We will use list slicing to explore sections (slices) of our dataset

# %%
# now when we slice, we do so by words!

wilson[:20]
# Out:
# The Boy and the Goddess Tell me about a complicated man. Muse, tell me how he wandered and

# %%
len(wilson)
# Out:
# 116544

# %% [markdown]
# ## the `Token` object
# We use loops to iterate through our dataset and pull out individual words.

# %%
for i in wilson[:10]:
  print(i)
# Out:
# The
# Boy
# and
# the
# Goddess
# Tell
# me
# about
# a
# complicated

# %% [markdown]
# ## `Token` attributes

# %%
# each token has a number of attributes

for i in wilson[:10]:
  print(i.text)
# Out:
# The
# Boy
# and
# the
# Goddess
# Tell
# me
# about
# a
# complicated

# %%
# some other useful attributes, including part of speech, and whether it is an alpha character.
# https://spacy.io/api/token/#attributes 

for i in wilson[:20]:
  print(i.text, i.pos_, i.is_alpha)
# Out:
# The DET True
# Boy PROPN True
# and CCONJ True
# the DET True
# Goddess PROPN True
# Tell VERB True
# me PRON True
# about ADP True
# a DET True
# complicated ADJ True
# man NOUN True
# . PUNCT False
# Muse PROPN True
# , PUNCT False
# tell VERB True
# me PRON True
# how SCONJ True
# he PRON True
# wandered VERB True
# and CCONJ True

# %% [markdown]
# ## individual practice
# - reading documentation is a skill!
# - find more attributes, experiment with at least two
# - https://spacy.io/api/token/#attributes

# %%
for i in wilson[:10]:
  print(i.text, i.lower_, i.lemma_, i.pos_, i.dep_, i.is_stop, i.is_alpha, i.is_punct, i.is_digit, i.head)
# Out:
# The the the DET det True True False False Boy
# Boy boy Boy PROPN nsubj False True False False Tell
# and and and CCONJ cc True True False False Boy
# the the the DET det True True False False Goddess
# Goddess goddess Goddess PROPN conj False True False False Boy
# Tell tell tell VERB ROOT False True False False Tell
# me me I PRON dobj True True False False Tell
# about about about ADP prep True True False False Tell
# a a a DET det True True False False man
# complicated complicated complicated ADJ amod False True False False man

# %% [markdown]
# ## comparing nouns with conditional statements
# - we will load up another version of the text, by Alexander Pope.
# - do you notice any differences between Wilson's and Pope's usage of nouns and verbs?

# %%
# load up pope text
with open("pope.txt", "r") as f:
    pope_text = f.read()
    f.close()

# cleaning /n from text
pope_text = pope_text.replace('\n', ' ')

# creating doc object
pope = nlp(pope_text)

# %%
# filtering:
# using conditional statement to print out nouns

for i in wilson[:100]:
  if i.pos_ == "NOUN":
    print(i)
# Out:
# man
# town
# pain
# storms
# sea
# life
# men
# fools
# cattle
# home
# goddess
# child

# %%
for i in pope[:100]:
  if i.pos_ == "NOUN":
    print(i)
# Out:
# man
# wisdom
# arts
# renown’d
# woes
# resound
# arms
# fall
# heaven
# wall
# clime
# clime
# observant
# manners
# states
# seas
# friends
# natal
# shore
# toils
# folly
# herds
# day

# %%
# using conditional statement to print out verbs

for i in wilson[:100]:
  if i.pos_ == "VERB":
    print(i)
# Out:
# Tell
# tell
# wandered
# lost
# wrecked
# went
# met
# suffered
# worked
# save
# bring
# failed
# keep
# ate
# kept

# %%
for i in pope[:100]:
  if i.pos_ == "VERB":
    print(i)
# Out:
# exercised
# wrought
# destined
# razed
# built
# Wandering
# noted
# unnumber’d
# toils
# bore
# gain
# dared
# prey
# devoted

# %% [markdown]
# ## back to `Doc`: pulling out `ents`
# - let's focus on Wilson's text for now.
# - we are going to pull out different entities.
# - then we are going to explore a particular entity in depth.

# %%
# what are entities?
wilson.ents[:10]
# Out:
# (Troy,
#  Zeus,
#  10,
#  Greeks,
#  Troy,
#  the year,
#  Ithaca,
#  Poseidon,
#  Odysseus,
#  Ethiopians)

# %%
# pull out entities

for i in wilson.ents[:10]:
  print(i, i.label_)
# Out:
# Troy GPE
# Zeus PERSON
# 10 CARDINAL
# Greeks PERSON
# Troy ORG
# the year DATE
# Ithaca GPE
# Poseidon PERSON
# Odysseus PERSON
# Ethiopians NORP

# %%
# how would I pull out entities for just characters?

for i in wilson.ents[:100]:
    if i.label_ == "PERSON":
        print(i)
# Out:
# Zeus
# Greeks
# Poseidon
# Odysseus
# Zeus
# Odysseus
# Atlas
# Odysseus
# Odysseus
# Poseidon
# Odysseus
# Poseidon
# Poseidon
# Odysseus
# Ogygia
# Odysseus
# Pylos
# Mentes
# Phemius
# Mentes
# Odysseus
# Greeks

# %%
# the ent object also has a property "sent"

for i in wilson.ents[:100]:
    if i.label_ == "PERSON":
        print(i.text, i.label_)
        print(i.sent)
# Out:
# Zeus PERSON
# Now goddess, child of Zeus, tell the old story for our modern times.
# Greeks PERSON
# All the other Greeks who had survived the brutal sack of Troy sailed safely home to their own wives—except this man alone.
# Poseidon PERSON
# All the gods took pity, except Poseidon’s anger never ended 20 until Odysseus was back at home.
# Odysseus PERSON
# All the gods took pity, except Poseidon’s anger never ended 20 until Odysseus was back at home.
# Zeus PERSON
# The other gods were gathered on Olympus, in Father Zeus’ palace.
# Odysseus PERSON
# But I am agonizing about Odysseus and his bad luck.
# Atlas PERSON
# For too long he has suffered, with no friends, sea all around him, sea on every side, 50 out on an island where a goddess lives, daughter of fearful Atlas, who holds up the pillars of the sea, and knows its depths— those pillars keep the heaven and earth apart.
# Odysseus PERSON
# So why do you dismiss Odysseus?”
# Odysseus PERSON
# the Cloud God said, “You must be joking, since how could I forget Odysseus?
# Poseidon PERSON
# But Lord Poseidon rages, unrelenting, because Odysseus destroyed the eye of godlike Polyphemus, his own son, 70 the strongest of the Cyclopes—whose mother, Thoösa, is a sea-nymph, child of Phorcys, the sea king; and she lay beside Poseidon inside a hollow cave.
# Odysseus PERSON
# But Lord Poseidon rages, unrelenting, because Odysseus destroyed the eye of godlike Polyphemus, his own son, 70 the strongest of the Cyclopes—whose mother, Thoösa, is a sea-nymph, child of Phorcys, the sea king; and she lay beside Poseidon inside a hollow cave.
# Poseidon PERSON
# But Lord Poseidon rages, unrelenting, because Odysseus destroyed the eye of godlike Polyphemus, his own son, 70 the strongest of the Cyclopes—whose mother, Thoösa, is a sea-nymph, child of Phorcys, the sea king; and she lay beside Poseidon inside a hollow cave.
# Poseidon PERSON
# So now Poseidon prevents Odysseus from reaching home but does not kill him.
# Odysseus PERSON
# Athena’s eyes lit up and she replied, 80 “Great Father, if the blessed gods at last will let Odysseus return back home, then hurry, we must send our messenger, Hermes the giant-slayer.
# Ogygia PERSON
# He must swoop down to Ogygia right away and tell the beautiful Calypso we have formed a firm decision that Odysseus has waited long enough.
# Odysseus PERSON
# He must swoop down to Ogygia right away and tell the beautiful Calypso we have formed a firm decision that Odysseus has waited long enough.
# Pylos PERSON
# Then I will send him off to Pylos and to Sparta, to seek news about his father’s journey home, and gain a noble reputation for himself.”
# Mentes PERSON
# She looked like Mentes now, the Taphian leader, a guest-friend.
# Phemius PERSON
# A slave brought out a well-tuned lyre and gave it to Phemius, the man the suitors forced to sing for them.
# Mentes PERSON
# I am Mentes, the son of wise Anchialus, 180 lord of the Taphians, who love the oar.
# Odysseus PERSON
# Tell me now—are you Odysseus’ son?
# Greeks PERSON
# The Greeks would then have built a tomb for him; he would have won 240 fame for his son.

# %% [markdown]
# ## Analyzing characterization with `ent` + `pos_`
# - we will create advanced filters to get more information about characters
# - Steps:
#   1. find a partner
#   2. choose a character from the story
#   3. revise the conditional to filters out that character by name
#   4. examine the results between two different versions of the story

# %%
# load up fagles text
with open("fagles.txt", "r") as f:
    fagles_text = f.read()
    f.close()

# cleaning /n from text
fagles_text = fagles_text.replace('\n', ' ')

# creating doc object
fagles = nlp(fagles_text)

# %%
# printing adjectives associated with Odysseus

for ent in wilson.ents:
    for token in ent:
        if token.text == 'Odysseus':
            for child in token.children:
                if child.pos_ == "ADJ":
                    print(ent.text, "->", child.text)
# Out:
# Odysseus -> dear
# Odysseus -> brave
# Odysseus at Troy 220 -> glorious
# Odysseus -> spirited
# Odysseus -> godlike
# Odysseus -> clever
# King Odysseus -> great
# Odysseus -> lord
# Odysseus -> lost
# Odysseus -> dear
# Odysseus -> willed
# Odysseus -> alive
# Odysseus -> firm
# Odysseus -> devious
# Odysseus -> great
# The Last Banquet Odysseus -> Last
# Odysseus -> competent
# Odysseus -> competent
# Odysseus -> eyed
# Odysseus -> willed
# Odysseus -> cunning
# Odysseus -> poor
# Odysseus -> unfortunate

# %%
# printing adjectives associated with Odysseus

for ent in fagles.ents:
    for token in ent:
        if token.text == 'Odysseus':
            for child in token.children:
                if child.pos_ == "ADJ":
                    print(ent.text, "->", child.text)
# Out:
# Odysseus -> great
# Great Odysseus -> Great
# Odysseus -> wise
# Odysseus -> great
# Odysseus -> own
# Odysseus -> dead
# King Odysseus -> hearted
# Odysseus -> brave
# King Odysseus -> resourceful
# royal Odysseus -> royal
# Odysseus -> weary
# Odysseus -> unlucky
# Odysseus -> great
# Odysseus -> great
# Odysseus -> great
# Odysseus -> thoughtful
# Great Odysseus -> Great
# Odysseus -> great
# Odysseus -> wise
# Odysseus -> wary
# Odysseus -> diplomatic
# Odysseus -> good
# Odysseus -> good
# Odysseus -> famed
# Odysseus -> hotheaded
# Odysseus -> renowned
# Odysseus -> great
# Odysseus -> famous
# Odysseus -> wise
# King Odysseus -> royal
# Odysseus -> great
# Odysseus -> great
# Odysseus -> subtle
# Odysseus -> dead
# Odysseus -> wily
# Odysseus -> tactician
# Odysseus -> quick
# Odysseus -> great
# Odysseus -> tactician
# Odysseus -> steady
# Odysseus -> canny
# Odysseus -> hearted
# Odysseus -> great
# Odysseus -> great
# Odysseus -> great
# royal Odysseus -> royal
# Odysseus -> great

# %%
# printing adjectives associated with Helen

for ent in wilson.ents:
    for token in ent:
        if token.text == 'Helen':
            for child in token.children:
                if child.pos_ == "ADJ":
                    print(ent.text, "->", child.text)
# Out:
# Helen -> marvelous
# Helen -> haired

# %%
# printing adjectives associated with Helen

for ent in fagles.ents:
    for token in ent:
        if token.text == 'Helen':
            for child in token.children:
                if child.pos_ == "ADJ":
                    print(ent.text, "->", child.text)
# Out:
# Helen -> famous

# %%
# printing adjectives associated with Penelope

for ent in wilson.ents:
    for token in ent:
        if token.text == 'Penelope':
            for child in token.children:
                if child.pos_ == "ADJ":
                    print(ent.text, "->", child.text)
# Out:
# Penelope -> wise
# Penelope -> wise
# Penelope -> wise
# Penelope -> wise
# Penelope -> sharp
# Penelope -> thoughtful
# Penelope -> circumspect
# Penelope -> wise
# Penelope -> shrewd
# Penelope -> beautiful
# Penelope -> wise
# Penelope -> great
# Penelope -> intelligent

# %%
# printing adjectives associated with Penelope

for ent in fagles.ents:
    for token in ent:
        if token.text == 'Penelope':
            for child in token.children:
                if child.pos_ == "ADJ":
                    print(ent.text, "->", child.text)
# Out:
# Penelope -> wary
# Penelope -> unaware
# Penelope -> circumspect
# Penelope -> wise
# Penelope -> wise
# Penelope -> wise
# Penelope -> thoughtful
# Penelope -> cautious
# Penelope -> discreet
# Penelope -> shrewd
# Penelope -> discreet
# Queen Penelope -> cautious
# Penelope -> alert
# Penelope -> wise
# Penelope -> wise
# Penelope -> queen
# Penelope -> wise
# Penelope -> discreet
# Penelope -> wise
# Penelope -> sensible
# Penelope -> cautious
# Penelope -> discreet
# Penelope -> wise
# Penelope -> cautious
# Penelope -> wise
# Penelope -> wise
# Penelope -> watchful
# Penelope -> alert
# Penelope -> wary
# Penelope -> wary
# Penelope -> shrewd

# %%
# printing verbs associated with Odysseus

for ent in wilson.ents:
    for token in ent:
        if token.text == 'Odysseus':
            for child in token.children:
                # changed the pos_ to VERB
                if child.pos_ == "VERB":
                    print(ent.text, "->", child.text)
# Out:
# Odysseus -> suffering
# Odysseus -> suffering
# Odysseus -> endured
# Meanwhile Odysseus -> sleeping
# Odysseus -> endured
# Odysseus -> gone
# Odysseus -> suffering
# Odysseus -> witted
# Odysseus -> lost
# Odysseus -> defend
# Odysseus -> endured
# Odysseus -> ducked
# Odysseus -> kept
# Scheming Odysseus -> Scheming
# Odysseus -> ducked
# Lying Odysseus -> Lying
# Scheming Odysseus -> Scheming
# Odysseus -> scarred
# Odysseus -> weathered

# %%
# printing verbs associated with Odysseus

for ent in fagles.ents:
    for token in ent:
        if token.text == 'Odysseus':
            for child in token.children:
                # changed the pos_ to VERB
                if child.pos_ == "VERB":
                    print(ent.text, "->", child.text)
# Out:
# Great Odysseus -> excels
# Odysseus -> enduring
# Odysseus -> enduring
# Odysseus -> overjoyed
# Odysseus -> tossed
# Odysseus -> borne
# Odysseus -> seasoned
# Cave Odysseus -> launched
# Cave Odysseus -> shining
# Odysseus -> known
# Odysseus -> shining
# Odysseus -> overjoyed
# Odysseus -> enduring
# Odysseus -> enduring
# Odysseus -> wept
# Odysseus -> flanked
# Odysseus -> enduring
# Odysseus -> suffering
# Odysseus -> enduring
# Odysseus -> enduring
